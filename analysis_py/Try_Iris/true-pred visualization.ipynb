# %%
# %matplotlib notebook
# %run 'Preprocessing.py'
import pandas as pd
import seaborn as sns
# Out:
# (150, 4) (150,)
# <img src="data:image/png;base64,...">

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier()

# %%
clf.fit(X_train, y_train)
# Out:
# SGDClassifier(alpha=0.0001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', n_iter=5, n_jobs=1,
#        penalty='l2', power_t=0.5, random_state=None, shuffle=True,
#        verbose=0, warm_start=False)

# %%
clf.coef_
# Out:
# array([[-32.28900526,  20.49537864],
#        [ 11.80558436, -11.45900011],
#        [ 15.41247654,   4.21536156]])

# %%
clf.intercept_
# Out:
# array([-19.03568341,  -8.76437464, -17.32685223])

# %%
y_train_pred = clf.predict(X_train)

# %%
# Violin plot
all_data = [np.array(y_train_pred[y_train == 0]), np.array(y_train_pred[y_train == 1]),np.array(y_train_pred[y_train == 2])]
all_data1 = pd.DataFrame({"true": y_train, "pred": y_train_pred})

# %%
plt.figure();sns.stripplot(x="true", y="pred", data=all_data1, jitter=True);
sns.violinplot(x = "true", y = "pred", data = all_data1, color = ".8")
# Out:
# <img src="data:image/png;base64,...">

# %%
# Out:
# <img src="data:image/png;base64,...">
# {'bodies': [<matplotlib.collections.PolyCollection at 0x25b6c533828>,
# ...
#  'cbars': <matplotlib.collections.LineCollection at 0x25b6c569a20>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x25b6c533208>,
#  'cmins': <matplotlib.collections.LineCollection at 0x25b6c569da0>}

# %%
# Out:
# [array([ -2.6544848 ,   1.26886581,   5.01817277,  -1.86410791,
#         -11.41213666,  -4.67235225,   1.99574608,  12.61951985,
#           1.36331829,  -2.44942603, -14.62814798,  -8.16108034,
#          -5.48904835,  -3.68285192,  -2.43129223,   2.17708096,
#           4.48039275,  -0.16258889,   5.50955757,  -5.22106079,
#           2.31277779,  -0.65616256,   6.84855237,   4.8314555 ,
#           7.04734967,   2.19775814,   5.03267459,   0.7776128 ,
#         -13.20417692,   9.16189482,  -1.29810536, -18.13852529,
#           2.97141789,  -2.09640363,   0.94648888,  -2.60012778,
#          12.78006267,  -0.67801403,  -4.09308514,  -2.85361962,
#          -3.88733597,  10.45353172,  -5.57945304,   5.93282982,
#           5.73322513,   9.52583731,   1.47252261,  -4.27516463,
#          -7.88934345,  -2.40658366,  16.72272367,   7.78270715,
#           4.44888964,  13.30788748,  -3.36648446,   0.2928026 ,
#           9.80842903,  -3.56341661,   1.2357072 ,  -6.76163161,
# ...
