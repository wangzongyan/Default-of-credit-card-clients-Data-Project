# %%
# %matplotlib notebook

# %%
import plotly.plotly as py

# %%
py.sign_in("wangzongyan", "obsmth5w9h")

# %%
# %run 'read_data.ipynb'

# %%
whos
# Out:
# Variable        Type         Data/Info
# --------------------------------------
# credit_data     Sheet        <xlrd.sheet.Sheet object at 0x0000029962A8A0B8>
# data_workbook   Book         <xlrd.book.Book object at 0x000002996168DEF0>
# df_data         DataFrame              ID  LIMIT_BAL  <...>[30000 rows x 25 columns]
# go              module       <module 'plotly.graph_obj<...>graph_objs\\__init__.py'>
# np              module       <module 'numpy' from 'D:\<...>ges\\numpy\\__init__.py'>
# pd              module       <module 'pandas' from 'D:<...>es\\pandas\\__init__.py'>
# plotdata        list         n=1
# plt             module       <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# py              module       <module 'plotly.plotly' f<...>ly\\plotly\\__init__.py'>
# sk              module       <module 'sklearn' from 'D<...>s\\sklearn\\__init__.py'>
# stats           module       <module 'statsmodels' fro<...>tatsmodels\\__init__.py'>
# ...

# %%
df_data.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.figure();plt.plot(df_data.iloc[:,0],df_data.iloc[:,1]);plt.legend(loc=2,prop={'size':6});plt.xlabel("ID");plt.ylabel("LIMIT_BAL")
# Out:
# <img src="data:image/png;base64,...">

# %%
data = [
    go.Scatter(
        x=df_data['ID'], # assign x as the dataframe column 'x'
        y=df_data['LIMIT_BAL']
    )
]

py.iplot(plotdata, filename='pandas/basic-line-plot')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~wangzongyan/1.embed" height="525px" width="100%"></iframe>

# %%
df_data.dtypes
# Out:
# <img src="data:image/png;base64,...">
